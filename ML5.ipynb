# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("iris.csv")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
df.plot(kind='scatter', x='sepal_length', y='sepal_width')
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='species',height=6).map(plt.scatter,'sepal_length','sepal_width').add_legend();
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='species',height=6).map(plt.scatter,'petal_length','petal_width').add_legend();
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='species',height=6).map(plt.scatter,'petal_length','sepal_width').add_legend();
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='species',height=6).map(plt.scatter,'sepal_length','petal_width').add_legend();
plt.show()

# %%
sns.set_style('whitegrid')
sns.pairplot(df,hue='species',height=4).add_legend();
plt.show()

# %%
import numpy as np
df_setosa = df.loc[df["species"] == "setosa"];
df_virginica = df.loc[df["species"] == "virginica"];
df_versicolor = df.loc[df["species"] == "versicolor"];
#print(iris_setosa["petal_length"])
plt.plot(df_setosa["petal_length"], np.zeros_like(df_setosa['petal_length']), 'o')
plt.plot(df_versicolor["petal_length"], np.zeros_like(df_versicolor['petal_length']), 'o')
plt.plot(df_virginica["petal_length"], np.zeros_like(df_virginica['petal_length']), 'o')

plt.show()

# %%
sns.FacetGrid(df, hue="species", height=7) \
   .map(sns.distplot, "petal_length") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(df, hue="species", height=7) \
   .map(sns.distplot, "petal_width") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(df, hue="species", height=3) \
   .map(sns.distplot, "sepal_length") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(df, hue="species", height=3) \
   .map(sns.distplot, "sepal_width") \
   .add_legend();
plt.show();

# %%
print(np.median(df_setosa["petal_length"]))
# Out:
# 1.5

# %%
print(np.median(np.append(df_setosa["petal_length"],50)))
# Out:
# 1.5

# %%
sns.boxplot(x='species',y='petal_length',data=df)

# %%
sns.violinplot(x='species',y='petal_length',data=df,size=8)

# %%
sns.jointplot(x='petal_length',y='petal_width',data=df_setosa,kind='kde',height=8)
plt.show()
